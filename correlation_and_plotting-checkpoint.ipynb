# %%
import pandas as pd

# %%
df =pd.read_csv("HCV-Egy-Data.csv")

# %%
df.isnull().sum()
# Out:
# Age                                 0
# Gender                              0
# BMI                                 0
# Fever                               0
# Nausea/Vomting                      0
# Headache                            0
# Diarrhea                            0
# Fatigue & generalized bone ache     0
# Jaundice                            0
# Epigastric pain                     0
# WBC                                 0
# RBC                                 0
# HGB                                 0
# Plat                                0
# AST 1                               0
# ALT 1                               0
# ALT4                                0
# ALT 12                              0
# ALT 24                              0
# ALT 36                              0
# ALT 48                              0
# ALT after 24 w                      0
# RNA Base                            0
# RNA 4                               0
# RNA 12                              0
# ...

# %%
df.dtypes
# Out:
# Age                                   int64
# Gender                                int64
# BMI                                   int64
# Fever                                 int64
# Nausea/Vomting                        int64
# Headache                              int64
# Diarrhea                              int64
# Fatigue & generalized bone ache       int64
# Jaundice                              int64
# Epigastric pain                       int64
# WBC                                   int64
# RBC                                 float64
# HGB                                   int64
# Plat                                float64
# AST 1                                 int64
# ALT 1                                 int64
# ALT4                                float64
# ALT 12                                int64
# ALT 24                                int64
# ALT 36                                int64
# ALT 48                                int64
# ...

# %%
#find correlation of all cols to all other cols
df.corr().head()
# Out:
#                     Age     Gender       BMI     Fever  Nausea/Vomting  \
# Age             1.000000 -0.009934 -0.025353 -0.021208       -0.025024
# Gender         -0.009934  1.000000  0.006496  0.021604       -0.036726
# BMI            -0.025353  0.006496  1.000000 -0.017581        0.005801
# Fever          -0.021208  0.021604 -0.017581  1.000000       -0.005214
# Nausea/Vomting -0.025024 -0.036726  0.005801 -0.005214        1.000000
#
#                 Headache   Diarrhea   Fatigue & generalized bone ache   \
# Age              0.017562   0.043574                         -0.007817
# Gender          -0.023999   0.018161                          0.045452
# BMI             -0.007851  -0.026094                         -0.007296
# Fever            0.019751  -0.019661                         -0.003545
# Nausea/Vomting   0.019536   0.009361                         -0.032481
#
#                 Jaundice   Epigastric pain   ...    ALT 36    ALT 48  \
# ...

# %%
#to plot use matplotlib
import matplotlib.pyplot as plt
plt.matshow(df.corr())
plt.figure(figsize=(10,6))
plt.show()

# %%
#correlation with the target col
corr = df.corr()
corr_target = abs(corr['Baselinehistological staging']) #[-1]

# %%
#select top 10 col using absolute correlation with target variable 
abs_corr_target = abs(corr_target["Baselinehistological staging"])
abs_corr_target.sort_values(ascending=False, inplace=True)
abs_corr_target[:10].index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5b9fb1498d86> in <module>
#       1 #select top 10 col using absolute correlation with target variable
#       2 abs_corr_target = abs(corr_target["Baselinehistological staging"])
# ----> 3 abs_corr_target.sort_values(ascending=False, inplace=True)
#       4 abs_corr_target[:10].index
#
# AttributeError: 'numpy.float64' object has no attribute 'sort_values'

# %%
#this is selcting by threashold value that is 0.03
df.columns[abs(df.corr()['Baselinehistological staging']) > 0.03][:-1]
# Out:
# Index(['BMI', 'Fever', 'Nausea/Vomting', 'Epigastric pain ', 'ALT 1',
#        'ALT after 24 w', 'RNA 4', 'RNA 12', 'RNA EF',
#        'Baseline histological Grading'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Age ', 'Gender', 'BMI', 'Fever', 'Nausea/Vomting', 'Headache ',
#        'Diarrhea ', 'Fatigue & generalized bone ache ', 'Jaundice ',
#        'Epigastric pain ', 'WBC', 'RBC', 'HGB', 'Plat', 'AST 1', 'ALT 1',
#        'ALT4', 'ALT 12', 'ALT 24', 'ALT 36', 'ALT 48', 'ALT after 24 w',
#        'RNA Base', 'RNA 4', 'RNA 12', 'RNA EOT', 'RNA EF',
#        'Baseline histological Grading', 'Baselinehistological staging'],
#       dtype='object')

# %%
#if target variable is "jaundice", print correlation of all cols with jaundice
corr['Jaundice ']
# Out:
# Age                                 0.010285
# Gender                              0.000768
# BMI                                -0.071379
# Fever                              -0.005124
# Nausea/Vomting                      0.000711
# Headache                            0.007960
# Diarrhea                           -0.016618
# Fatigue & generalized bone ache     0.007947
# Jaundice                            1.000000
# Epigastric pain                    -0.025289
# WBC                                 0.030286
# RBC                                -0.012878
# HGB                                -0.025192
# Plat                               -0.036599
# AST 1                               0.014746
# ALT 1                               0.012601
# ALT4                                0.015213
# ALT 12                             -0.008993
# ALT 24                             -0.007831
# ALT 36                              0.007296
# ALT 48                              0.016253
# ...

# %%
df.hist() #shortcut to print all histrogram
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024815EBE688>,
# ...
#       dtype=object)

# %%
#plot histogram of all cols one by one using for loop
#for one col: df['Age '].hist()

for index, col in enumerate(df.columns): #gives index as well as col names (element) using emunerate
    print(col)
    df[col].hist()
    name = str(index) + ".png"
    plt.savefig(name)
    plt.close()
# Out:
# Age
# Gender
# BMI
# Fever
# Nausea/Vomting
# Headache
# Diarrhea
# Fatigue & generalized bone ache
# Jaundice
# Epigastric pain
# WBC
# RBC
# HGB
# Plat
# AST 1
# ALT 1
# ALT4
# ALT 12
# ALT 24
# ALT 36
# ALT 48
# ALT after 24 w
# RNA Base
# RNA 4
# RNA 12
# RNA EOT
# RNA EF
# Baseline histological Grading
# Baselinehistological staging

# %%
#to check if the files are created or not on windows
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C654-0349
#
#  Directory of C:\Users\DELL\ML_class_practice\ML\hepatitis_data
#
# 13-Sep-20  02:57 PM    <DIR>          .
# 13-Sep-20  02:57 PM    <DIR>          ..
# 13-Sep-20  02:01 PM    <DIR>          .ipynb_checkpoints
# 13-Sep-20  02:57 PM             6,871 0.png
# 13-Sep-20  02:57 PM             6,808 1.png
# 13-Sep-20  02:57 PM             6,783 10.png
# 13-Sep-20  02:57 PM             7,337 11.png
# 13-Sep-20  02:57 PM             5,265 12.png
# 13-Sep-20  02:57 PM             7,475 13.png
# 13-Sep-20  02:57 PM             6,311 14.png
# 13-Sep-20  02:57 PM             6,809 15.png
# 13-Sep-20  02:57 PM             6,810 16.png
# 13-Sep-20  02:57 PM             6,777 17.png
# 13-Sep-20  02:57 PM             6,769 18.png
# 13-Sep-20  02:57 PM             7,369 19.png
# 13-Sep-20  02:57 PM             5,517 2.png
# 13-Sep-20  02:57 PM             7,376 20.png
# 13-Sep-20  02:57 PM             6,409 21.png
# ...

# %%
df.boxplot()

# %%
df[['Age ','WBC','RBC']].boxplot() #take care of the ranges when plotting it for every cols

# %%
#Boxplot for every cols
for index, col in enumerate(df.columns): #gives index as well as col names (element) using emunerate
    print(col)
    df[[col]].boxplot()
    name = str(index) + ".png"
    plt.savefig(name)
    plt.close()
# Out:
# Age
# Gender
# BMI
# Fever
# Nausea/Vomting
# Headache
# Diarrhea
# Fatigue & generalized bone ache
# Jaundice
# Epigastric pain
# WBC
# RBC
# HGB
# Plat
# AST 1
# ALT 1
# ALT4
# ALT 12
# ALT 24
# ALT 36
# ALT 48
# ALT after 24 w
# RNA Base
# RNA 4
# RNA 12
# RNA EOT
# RNA EF
# Baseline histological Grading
# Baselinehistological staging

# %%
df.head()
#Assume 1-Male and 2-Female
#Select all the rows with male patients (SELECT ROWS BASED ON CONDITIONS)
df.loc[df['Gender'] == 1] #boolean indexing is not allowed in iloc[] so that can not be used here
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 4       59       1   32      1               1          2          1
# 8       44       1   23      1               1          2          2
# ...    ...     ...  ...    ...             ...        ...        ...
# 1379    53       1   31      2               2          1          2
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# ...

# %%
#find all patients whoes age is more that mean age
mean_age = df['Age '].mean() #to simplify first calculate the mean and then perform the condition
df.loc[df['Age '] >= mean_age]
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# 5       58       2   22      2               2          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1377    52       2   25      1               2          1          1
# 1379    53       1   31      2               2          1          2
# 1381    55       1   34      1               2          2          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# ...

# %%
#Feature importance
# Separate X(known) and Y(unknown)
#this code works even ifyour trarget col is in middle of the dataframe
target_col = 'Baselinehistological staging' #define target col give it's name
X = df.loc[:, ~df.columns.isin([target_col])] #select all those cols except the target col
Y = df.loc[:,target_col] #this is the target col

# %%
from sklearn.model_selection import train_test_split
# Split Training and Testing Data
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.30, random_state=7)

# %%
#feature imp using RFE, gini index, Entropy
